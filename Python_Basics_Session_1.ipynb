# %%
#WAP find the area of triangle
base=20
height=100
area=0.5*base*height
print("Area of the triangle is:",area)
# Out:
# Area of the triangle is: 1000.0

# %%
number=100 #Y
NUMber=200 #Y
NUMBER=300 #Y
number123=400 #Y
123number=500 #N
number%one=600 #N
number$two=700 #N
number_one=800 #Yes
if=900 #NO
else=1000 #NO
'number'=1100 #No
##################DO NOT USE###########
sum=1200
max=1300
min=1400
print=1500
# Out:
#   Cell In[2], line 5
#     123number=500 #N
#       ^
# SyntaxError: invalid decimal literal

# %%
l=[10,20,30,40,50]
print(sum(l))
print(max(l))
print(min(l))
print(len(l))
print(l)
print(type(l))
# Out:
# 150
# 50
# 10
# 5
# [10, 20, 30, 40, 50]
# <class 'list'>

# %%
- Inbuilt functions expect normal brackets



- if you miss the brackets it will give two indications
    
    
    - **function**
        
        
    - **bound method**

# %%
import time
time.sleep
# Out:
# <function time.sleep>

# %%
sum
# Out:
# <function sum(iterable, /, start=0)>

# %%
max
# Out:
# <function max>

# %%
len
# Out:
# <function len(obj, /)>

# %% [markdown]
# - **data types:14**

# %% [markdown]
# - int
#
#
# - float
#
#
# - str
#
#
# - bool
#
#
# - complex
#
#
# - range
#
#
# - list
#
#
# - tuple
#
#
# - dict
#
#
# - set
#
#
# - frozenset
#
#
# - bytes
#
#
# - bytearray
#
#
# - None
