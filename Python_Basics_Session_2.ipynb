# %%
# Wap ask the user find the area of circle
# Hint : 3.14*r*r

# Wap ask the user find the area of rectangle
# Hint: Length*breadth

#Wap ask the user take income=1lak, tax percentage=10 calculate tax
# Hint : salary=
# tax per =
# tax_amount=

#Wap to centigrate convert 35c to Faranhit
# Hint: Take the formula from ggl

#Wap ask user get hotabill and tip percentage calculate total bill
# Hint:
# bill_amount=
# top_per=
# total_bill=

# %%
# Wap ask the user find the area of circle
# Hint : 3.14*r*r
r=10
area=3.14*r*r
print(area)
# Out:
# 314.0

# %%
# Wap ask the user find the area of rectangle
# Hint: Length*breadth
l = 10
b = 20
area=l*b
print(area)
# Out:
# 200

# %%
#Wap ask the user take income=1lak, tax percentage=10 calculate tax
bill=10000
tax_per=20
tax=bill*tax_per/100
total_bill=bill+tax
total_bill
# Out:
# 12000.0

# %%
#Wap to convert 35c to Faranhit

celsius = 35
fahrenheit = (celsius * 9/5) + 32

print("Temperature in Celsius:", celsius, "°C")
print("Temperature in Fahrenheit:", fahrenheit, "°F")
# Out:
# Temperature in Celsius: 35 °C
# Temperature in Fahrenheit: 95.0 °F

# %%
#Wap ask user get hotelbill and tip percentage calculate total bill
hotel_bill=float(input("Enter hotel bill amount: "))
tip_percentage=float(input("Enter the tip  percentage: "))
tip = (hotel_bill * tip_percentage) / 100
total_bill = hotel_bill + tip

print("Hotel Bill:", hotel_bill)
print("Tip Amount:", tip)
print("Total Bill:", total_bill)
# Out:
# Enter hotel bill amount: 2000
# Enter the tip  percentage: 10
# Hotel Bill: 2000.0
# Tip Amount: 200.0
# Total Bill: 2200.0
