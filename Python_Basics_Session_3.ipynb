# %%
- Logical Error:We written a  proper code but the logic is failed
    
 
 - Syntax Error:Python is expecting from you write a proper code


- Inbuilt Functions

   - print
    
    - sum
    
    - max
    
    - min
    
    - len
    
    - type
    
- If we miss the bracets
   
    - function
    
    - Bound method
# Out:
#   Cell In[1], line 1
#     - Logical Error:We written a  proper code but the logic is failed
#               ^
# SyntaxError: invalid syntax

# %%
- **Type Casting**
     
    
    - change one dattype to another datatype

# %%
a=10
float(a),str(a),bool(a)
# Out:
# (10.0, '10', True)

# %%
b=-10
float(b),str(b),bool(b)
# Out:
# (-10.0, '-10', True)

# %%
float(0),str(0),bool(0)
# Out:
# (0.0, '0', False)

# %% [markdown]
# - **float to other datatypes**

# %%
a=10.5
int(a),str(a),bool(a)
# Out:
# (10, '10.5', True)

# %% [markdown]
# **String to other datatypes**

# %%
int("10"),float("10"),bool("10")
# Out:
# (10, 10.0, True)

# %%
bool(10),bool('10'),bool(0),bool('')
# Out:
# (True, True, False, False)

# %%
int('10') #10 
float('10') #10.0
bool('10') #True
int('10.5') #Error
bool('10.5')# True
float('10.5')# 10.5
int('apple') #Error
float('apple') #Error
bool('apple') # True
int('0') #0
float('0') #0.0
bool('0') # T
int('') # Error
float('') #E
bool('') #False
int(' ') #E
float(' ')#E
bool(' ')#T
bool(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 4
#       2 float('10') #10.0
#       3 bool('10') #True
# ----> 4 int('10.5') #Error
#       5 bool('10.5')# True
#       6 float('10.5')# 10.5
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
bool(0)
# Out:
# False

# %%
'10'+'20'
# Out:
# '1020'

# %%
int('10')+int('20')
# Out:
# 30

# %% [markdown]
# - **input**

# %%
input
# Out:
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000001D9526AA790>>

# %%
input()
# Out:
# 20
# '20'

# %%
a=input()
b=input()
a+b
# Out:
# 10
# 20
# '1020'

# %%
a=int(input("Enter ur first number: "))
b=int(input("Enter ur second number: "))
a+b
# Out:
# Enter ur first number: 10.5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 a=int(input("Enter ur first number: "))
#       2 b=int(input("Enter ur second number: "))
#       3 a+b
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
n1=float(input("Enter the n1: "))
n2=float(input("Enter the n2: "))
print(f'the sum of {n1} & {n2} is:{n1+n2}')
# Out:
# Enter the n1: 10.5
# Enter the n2: 20.5
# the sum of 10.5 & 20.5 is:31.0

# %%
n1=eval(input("Enter the n1: "))
n2=eval(input("Enter the n2: "))
print(f'the sum of {n1} & {n2} is:{n1+n2}')
# Out:
# Enter the n1: 20
# Enter the n2: 30.5
# the sum of 20 & 30.5 is:50.5

# %%
name=input("enter ur name: ")
age=eval(input("enter your age: "))
city=input("enter city: ")
print(f'my name is {name},I am {age} years old,I am from {city}')
# Out:
# enter ur name: Sushree
# enter your age: 23
# enter city: Odisha
# my name is Sushree,I am 23 years old,I am from Odisha
